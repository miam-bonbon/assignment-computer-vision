# %% [markdown]
# <a href="https://colab.research.google.com/github/miam-bonbon/assignment-computer-vision/blob/main/assignment_computer_vision_long_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Loading the dataset

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pwd
# Out:
# /content

# %%
# %cd drive/MyDrive/assignment-computer-vision
# !ls -l
# Out:
# /content/drive/MyDrive/assignment-computer-vision
# total 73436
# drwx------ 2 root root     4096 Nov 23 13:30 data
# drwx------ 2 root root     4096 Nov 26 16:28 datasets
# drwx------ 2 root root     4096 Nov 26 15:35 fruit-detection-yolov5
# -rw------- 1 root root   363112 Nov 26 11:53 model.png
# -rw------- 1 root root     7733 Nov 23 13:33 plot_functions.py
# drwx------ 2 root root     4096 Nov 23 13:43 __pycache__
# drwx------ 2 root root     4096 Nov 26 06:52 raw_test_ds_one_banana_only_saved
# drwx------ 2 root root     4096 Nov 25 19:35 raw_test_ds_saved
# drwx------ 2 root root     4096 Nov 26 06:52 raw_train_ds_one_banana_only_saved
# drwx------ 2 root root     4096 Nov 24 19:18 raw_train_ds_saved
# drwx------ 2 root root     4096 Nov 26 06:52 raw_validation_ds_one_banana_only_saved
# drwx------ 2 root root     4096 Nov 24 19:19 raw_validation_ds_saved
# -rw------- 1 root root  5613764 Nov 26 16:30 yolo11n.pt
# -rw------- 1 root root 50589507 Nov 26 20:24 yolov5mu.pt
# -rw------- 1 root root 18581255 Nov 26 13:33 yolov5su.pt

# %%
# %%capture

# %load_ext autoreload
# %autoreload 2
import os
import glob
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm.auto as tqdm

import tensorflow as tf

# from sklearn.model_selection import train_test_split

class print_style:
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %%
import plot_functions

# %%
# !nvidia-smi
tf.config.list_physical_devices('GPU')
# Out:
# Fri Nov 29 09:44:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0              43W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Dataset configuration
base_path = 'data'
num_classes = 2
input_size = 244

recreate_dataset = True # we load from drive

# %%
# Prepare for further processing
# Train
train_image_dir = os.path.join(base_path, 'train')
train_annotation_file = os.path.join(base_path, 'train/_annotations.csv')

if not os.path.exists(train_annotation_file):
    print(f"Error: Annotation file not found at {train_annotation_file}")

train_annotations = pd.read_csv(train_annotation_file)
train_image_files = glob.glob(os.path.join(train_image_dir, '*.jpg'))

# TEst
test_image_dir = os.path.join(base_path, 'test')
test_annotation_file = os.path.join(base_path, 'test/_annotations.csv')

if not os.path.exists(test_annotation_file):
    print(f"Error: Annotation file not found at {test_annotation_file}")

test_annotations = pd.read_csv(test_annotation_file)
test_image_files = glob.glob(os.path.join(test_image_dir, '*.jpg'))

# Validation
validation_image_dir = os.path.join(base_path, 'valid')
validation_annotation_file = os.path.join(base_path, 'valid/_annotations.csv')

if not os.path.exists(validation_annotation_file):
    print(f"Error: Annotation file not found at {validation_annotation_file}")

validation_annotations = pd.read_csv(validation_annotation_file)
validation_image_files = glob.glob(os.path.join(validation_image_dir, '*.jpg'))

# %%
# Get all boxes for an image

def get_boxes_for_image(filename, annotations):
    """
    Gets all boxes for a specific image from the annotations DataFrame.

    Args:
        filename: The name of the image file.
        annotations: The pandas DataFrame containing the annotations.

    Returns:
        A dictionary where keys are box indices and values are dictionaries
        containing 'xmin', 'ymin', 'xmax', 'ymax', and 'class' for each box.
        Returns an empty dictionary if no boxes are found for the image.
    """
    image_annotations = annotations[annotations['filename'] == filename]
    boxes_dict = {}
    for index, row in image_annotations.iterrows():
        boxes_dict[index] = {
            'box': row[['xmin', 'ymin', 'xmax', 'ymax']].values,
            'label': row['class']
        }
    return boxes_dict

# %%
# A function for displaying an image with parameters image and boxes (each box has a label)

import matplotlib.pyplot as plt
import matplotlib.patches as patches

def display_image_with_boxes(plt_img, boxes):
    """Displays an image with bounding boxes and labels.

    Args:
        image_path: Path to the image file.
        boxes: A list of dictionaries, where each dictionary represents a box
               and contains 'xmin', 'ymin', 'xmax', 'ymax', and 'label' keys.
    """
    try:
        boxes = list(boxes.values())
        fig, ax = plt.subplots(1)
        ax.imshow(plt_img)

        for box in boxes:
            xmin = box['box'][0]
            ymin = box['box'][1]
            xmax = box['box'][2]
            ymax = box['box'][3]
            label = box['label']

            rect = patches.Rectangle((xmin, ymin),
                                     xmax - xmin,
                                     ymax - ymin,
                                     linewidth=2, edgecolor='r', facecolor='none')
            ax.add_patch(rect)

            # Add the label to the box
            ax.text(xmin, ymin, label, color='r', fontsize=10, bbox=dict(facecolor='white', alpha=0.5))

        plt.show()

    except KeyError as e:
        print(f"Error: Missing key in box dictionary: {e}")

# %%
# # Show an image from train_annotations using display_image_with_boxes

# # The first image file is at index 0
# first_image_path = train_image_files[0]
# first_filename = os.path.basename(first_image_path)
# first_plt_img = plt.imread(first_image_path)
# first_boxes = get_boxes_for_image(first_filename, train_annotations)
# # print(first_boxes)

# # Display the image with bounding boxes using the function
# display_image_with_boxes(first_plt_img, first_boxes)

# %%
import cv2 as cv
import numpy as np

def _resize_image_and_boxes(image, boxes, new_width, new_height):
    """Resizes the image and adjusts the bounding boxes accordingly."""
    # Get the original height and width using the 'shape' attribute
    original_height, original_width = image.shape[0], image.shape[1]

    # Resize using OpenCV
    resized_image = cv.resize(image, (new_width, new_height))

    # Adjust bounding boxes and maintain the original format
    resized_boxes = {}
    for box_index, box_data in boxes.items():
      # print(box_data['box'])
      xmin, ymin, xmax, ymax = box_data['box']
      xmin = int(xmin * new_width / original_width)
      ymin = int(ymin * new_height / original_height)
      xmax = int(xmax * new_width / original_width)
      ymax = int(ymax * new_height / original_height)

      # Ensure boxes stay within image bounds after resizing
      xmin = max(0, min(xmin, new_width - 1))
      ymin = max(0, min(ymin, new_height - 1))
      xmax = max(0, min(xmax, new_width - 1))
      ymax = max(0, min(ymax, new_height - 1))

      # Store the resized box in the same format as the input 'boxes'
      resized_boxes[box_index] = {
          'box': np.array([xmin, ymin, xmax, ymax]),
          'label': box_data['label']
      }

    return resized_image, resized_boxes

# %%
# Let's resize our first image using _resize_image_and_boxes

# The first image file is at index 0
first_image_path = train_image_files[0]
first_filename = os.path.basename(first_image_path)
first_plt_img = plt.imread(first_image_path)
first_boxes = get_boxes_for_image(first_filename, train_annotations)

# Display the image with bounding boxes using the function
display_image_with_boxes(first_plt_img, first_boxes)

# Resize
resized_image, resized_boxes = _resize_image_and_boxes(first_plt_img, first_boxes, input_size, input_size)

# Print the resized boxes
print(first_boxes)
print(resized_boxes)

# Display the resized image with the adjusted bounding boxes:
display_image_with_boxes(resized_image, resized_boxes)
# Out:
# {5109: {'box': array([346, 308, 536, 508], dtype=object), 'label': 'pineapple'}, 5110: {'box': array([231, 397, 340, 498], dtype=object), 'label': 'pear'}, 5111: {'box': array([293, 169, 460, 312], dtype=object), 'label': 'banana'}}
# {5109: {'box': array([131, 117, 204, 193]), 'label': 'pineapple'}, 5110: {'box': array([ 88, 151, 129, 189]), 'label': 'pear'}, 5111: {'box': array([111,  64, 175, 118]), 'label': 'banana'}}

# %%
# Another random example
x = random.randint(0, len(train_image_files))

# Image file is at index x
random_image_path = train_image_files[x]
random_filename = os.path.basename(random_image_path)
random_plt_img = plt.imread(random_image_path)
random_boxes = get_boxes_for_image(random_filename, train_annotations)

# Display the image with bounding boxes using the function
display_image_with_boxes(random_plt_img, random_boxes)

# Resize
resized_image, resized_boxes = _resize_image_and_boxes(random_plt_img, random_boxes, input_size, input_size)

# Print the resized boxes
print(random_boxes)
print(resized_boxes)

# Display the resized image with the adjusted bounding boxes:
display_image_with_boxes(resized_image, resized_boxes)
# Out:
# {3679: {'box': array([196, 242, 396, 439], dtype=object), 'label': 'apple'}, 3680: {'box': array([20, 266, 204, 583], dtype=object), 'label': 'banana'}, 3681: {'box': array([411, 240, 640, 545], dtype=object), 'label': 'banana'}, 3682: {'box': array([352, 26, 537, 210], dtype=object), 'label': 'orange'}}
# {3679: {'box': array([ 74,  92, 150, 167]), 'label': 'apple'}, 3680: {'box': array([  7, 101,  77, 222]), 'label': 'banana'}, 3681: {'box': array([156,  91, 243, 207]), 'label': 'banana'}, 3682: {'box': array([134,   9, 204,  80]), 'label': 'orange'}}

# %%
import os

# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # disabling verbose tf logging

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.1

# %% [markdown]
# ## Data preparation
#
# This is where the magic happens - we prepare the data for our model.
#
# ### Key points:<br/>
# **Adding the Channel Dimension:** If your image data is grayscale, it might initially only have three dimensions (batch size, height, width). Using np.expand_dims(X, axis=3) adds a fourth dimension to represent the channel, even if it's just a single grayscale channel.
#
# **Why it's Important**
#
# Compatibility with CNN Layers: CNN layers are designed to operate on multi-channel data. By adding the channel dimension, you ensure that your data is compatible with these layers.
# Flexibility: Even if you're currently working with grayscale images, adding the channel dimension allows you to easily switch to using color images in the future without having to significantly modify your code.

# %%
# # prompt: please check for filenames without a label banana

# # Iterate through the annotations and find filenames without 'banana' label
# filenames_without_banana = []
# for filename in set(train_annotations['filename']):
#     boxes = get_boxes_for_image(filename, train_annotations)
#     if boxes:  # Check if there are any boxes for this filename
#         labels = [box_data['label'] for box_data in boxes.values()]
#         if 'banana' not in labels:
#             filenames_without_banana.append(filename)
#     else:
#       filenames_without_banana.append(filename)

# print(f"Filenames without 'banana' label in training set: {filenames_without_banana}")

# #Repeat for test and validation sets
# filenames_without_banana_test = []
# for filename in set(test_annotations['filename']):
#     boxes = get_boxes_for_image(filename, test_annotations)
#     if boxes:  # Check if there are any boxes for this filename
#         labels = [box_data['label'] for box_data in boxes.values()]
#         if 'banana' not in labels:
#             filenames_without_banana_test.append(filename)
#     else:
#       filenames_without_banana_test.append(filename)

# print(f"Filenames without 'banana' label in test set: {filenames_without_banana_test}")

# filenames_without_banana_validation = []
# for filename in set(validation_annotations['filename']):
#     boxes = get_boxes_for_image(filename, validation_annotations)
#     if boxes:  # Check if there are any boxes for this filename
#         labels = [box_data['label'] for box_data in boxes.values()]
#         if 'banana' not in labels:
#             filenames_without_banana_validation.append(filename)
#     else:
#       filenames_without_banana_validation.append(filename)

# print(f"Filenames without 'banana' label in validation set: {filenames_without_banana_validation}")

# %%
def data_load(image_files, annotations):
    X = []
    Y = []

    for image_file in image_files:
        img = cv.imread(os.path.join(image_file), cv.IMREAD_GRAYSCALE)
        boxes = get_boxes_for_image(os.path.basename(image_file), annotations)

        # resize everything
        img, boxes = _resize_image_and_boxes(img, boxes, input_size, input_size)

        # Check if a banana box exists
        banana_box_found = False
        for box_data in boxes.values():
            if box_data['label'] == 'banana':
                banana_box_found = True
                label = 1
                box = np.array(box_data['box'], dtype=float)
                break  # Stop searching after finding the first banana box

        # Handle images with no banana box
        if not banana_box_found:
            label = 0  # Set label to 0 for "no banana"
            box = np.array([0, 0, 0, 0], dtype=float)  # Create a dummy bounding box

        # resize_img, boxes = _resize_image_and_boxes(img, boxes, input_size, input_size)
        # print(boxes)
        # return
        img = img.astype(float) / 255.
        # print(img)
        # print(box)
        # we already have a float array
        box = np.asarray(box, dtype=float)
        # we wait with normalizing the bounding boxes
        # box = box / input_size
        # print(box)
        # box = np.append(box, label)
        label = np.append(box, label)
        # print(label)

        X.append(img)
        Y.append(label)

    X = np.array(X)
    # X = np.expand_dims(X, axis=3)
    Y = np.array(Y)
    # print(X)
    # print(Y)

    X = tf.convert_to_tensor(X, dtype=tf.float32)
    Y = tf.convert_to_tensor(Y, dtype=tf.float32)
    result = tf.data.Dataset.from_tensor_slices((X, Y))

    return result

# %%
if recreate_dataset:
  print('recreating ds')
  raw_train_ds = data_load(train_image_files, train_annotations)
  raw_validation_ds = data_load(validation_image_files, validation_annotations)
  raw_test_ds = data_load(test_image_files, test_annotations)
else:
  # load from drive
  print('loading from drive')
  raw_train_ds = tf.data.Dataset.load('/content/drive/MyDrive/assignment-computer-vision/raw_train_ds_saved')
  raw_validation_ds = tf.data.Dataset.load('/content/drive/MyDrive/assignment-computer-vision/raw_validation_ds_saved')
  raw_test_ds = tf.data.Dataset.load('/content/drive/MyDrive/assignment-computer-vision/raw_test_ds_saved')
# Out:
# recreating ds

# %% [markdown]
# The training, validation & test datasets must be set up in order to follow the tensorflow guideline (https://www.tensorflow.org/datasets/performances):

# %%
# !pwd
# Out:
# /content/drive/MyDrive/assignment-computer-vision

# %%
# tf.data.Dataset.save(raw_train_ds, '/content/drive/MyDrive/assignment-computer-vision/raw_train_ds_saved')
# tf.data.Dataset.save(raw_validation_ds, '/content/drive/MyDrive/assignment-computer-vision/raw_validation_ds_saved')
# tf.data.Dataset.save(raw_test_ds, '/content/drive/MyDrive/assignment-computer-vision/raw_test_ds_saved')

tf.data.Dataset.save(raw_train_ds, '/content/drive/MyDrive/assignment-computer-vision/raw_train_ds_saved_long_run')
tf.data.Dataset.save(raw_validation_ds, '/content/drive/MyDrive/assignment-computer-vision/raw_validation_ds_saved_long_run')
tf.data.Dataset.save(raw_test_ds, '/content/drive/MyDrive/assignment-computer-vision/raw_test_ds_saved_long_run')

# %%
CLASSES = 2

def format_instance(image, label):
    return image, (tf.one_hot(int(label[4]), CLASSES), [label[0], label[1], label[2], label[3]])

# %%
BATCH_SIZE = 32

def tune_training_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.shuffle(1024, reshuffle_each_iteration=True)
    dataset = dataset.repeat() # The dataset be repeated indefinitely.
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_ds = tune_training_ds(raw_train_ds)

# %%
def tune_validation_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(len(validation_image_files) // 4)
    # dataset = dataset.repeat()
    return dataset

# %%
validation_ds = tune_validation_ds(raw_validation_ds)

# %%
def tune_test_ds(dataset):
    dataset = dataset.map(format_instance, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(len(test_image_files) // 4)
    dataset = dataset.repeat()
    return dataset

# %%
test_ds = tune_test_ds(raw_test_ds)

# %% [markdown]
# ### Dataset ispection

# %%
# Inspect the first image from the training_ds with boxes

import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Assuming 'train_ds' is your TensorFlow dataset and the first element is available
for image, (label, box) in train_ds.take(3):
    # Convert the image to a NumPy array and remove the batch dimension
    image = image.numpy()[0, :, :, 0]  # Assuming grayscale image and removing channel dim

    # print(label, box)

    # Accessing the bounding box coordinates and label
    xmin = box[0][0].numpy()
    ymin = box[0][1].numpy()
    xmax = box[0][2].numpy()
    ymax = box[0][3].numpy()
    # print(xmin, ymin, xmax, ymax)
    label = label[0].numpy()
    # print(label)


    # Create the plot
    fig, ax = plt.subplots(1)
    ax.imshow(image, cmap='gray')  # Display grayscale image

    # Create a rectangle patch
    rect = patches.Rectangle((xmin, ymin), (xmax - xmin), (ymax - ymin), linewidth=2, edgecolor='r', facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)

    # Display the plot
    plt.show()

# %% [markdown]
# ## The model
#
# We are building a object detector, our model has two heads: one to classify the object type (or label or class) and other head to output the object bounding box.

# %%
DROPOUT_FACTOR = 0.5

def build_feature_extractor(inputs):

    x = tf.keras.layers.Conv2D(16, kernel_size=3, activation='relu',
                              kernel_regularizer=tf.keras.regularizers.l2(0.01), # L2 regularization
                              input_shape=(input_size, input_size, 1))(inputs)

    x = tf.keras.layers.Dropout(DROPOUT_FACTOR)(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    x = tf.keras.layers.Conv2D(32, kernel_size=3, activation = 'relu',
                              kernel_regularizer=tf.keras.regularizers.l2(0.01))(x) # L2 regularization
    x = tf.keras.layers.Dropout(DROPOUT_FACTOR)(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    x = tf.keras.layers.Conv2D(64, kernel_size=3, activation = 'relu',
                              kernel_regularizer=tf.keras.regularizers.l2(0.01))(x) # L2 regularization
    x = tf.keras.layers.Dropout(DROPOUT_FACTOR)(x)
    x = tf.keras.layers.AveragePooling2D(2,2)(x)

    return x

def build_model_adaptor(inputs):
  x = tf.keras.layers.Flatten()(inputs)
  x = tf.keras.layers.Dense(64, activation='relu'
  , kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
  return x

def build_classifier_head(inputs):
  return tf.keras.layers.Dense(CLASSES, activation='sigmoid', name = 'classifier_head')(inputs)

def build_regressor_head(inputs):
    return tf.keras.layers.Dense(units=4, name = 'regressor_head')(inputs)

def build_model(inputs):

    feature_extractor = build_feature_extractor(inputs)

    model_adaptor = build_model_adaptor(feature_extractor)

    classification_head = build_classifier_head(model_adaptor)

    regressor_head = build_regressor_head(model_adaptor)

    model = tf.keras.Model(inputs = inputs, outputs = [classification_head, regressor_head])

    # model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    #           loss = {'classifier_head' : 'binary_crossentropy', 'regressor_head' : 'mse' },
    #           metrics = {'classifier_head' : 'accuracy', 'regressor_head' : 'mse' })


    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss = {'classifier_head' : 'binary_crossentropy', 'regressor_head' : 'mse' },
              metrics = {'classifier_head' : 'accuracy', 'regressor_head' : 'mse' })

    return model

# %% [markdown]
# It is notewhortly that each network head has a specific set of loss function and metrics:

# %%
model = build_model(tf.keras.Input(shape=(input_size, input_size, 1)))

model.summary()
# Out:
# Model: "functional_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_25            │ (None, 244, 244, 1)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_75 (Conv2D)        │ (None, 242, 242, 16)   │            160 │ input_layer_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_51 (Dropout)      │ (None, 242, 242, 16)   │              0 │ conv2d_75[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_75      │ (None, 121, 121, 16)   │              0 │ dropout_51[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_76 (Conv2D)        │ (None, 119, 119, 32)   │          4,640 │ average_pooling2d_75[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_52 (Dropout)      │ (None, 119, 119, 32)   │              0 │ conv2d_76[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_76      │ (None, 59, 59, 32)     │              0 │ dropout_52[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_77 (Conv2D)        │ (None, 57, 57, 64)     │         18,496 │ average_pooling2d_76[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_53 (Dropout)      │ (None, 57, 57, 64)     │              0 │ conv2d_77[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_77      │ (None, 28, 28, 64)     │              0 │ dropout_53[0][0]       │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_25 (Flatten)      │ (None, 50176)          │              0 │ average_pooling2d_77[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_25 (Dense)          │ (None, 64)             │      3,211,328 │ flatten_25[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ classifier_head (Dense)   │ (None, 2)              │            130 │ dense_25[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ regressor_head (Dense)    │ (None, 4)              │            260 │ dense_25[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 3,235,014 (12.34 MB)
#  Trainable params: 3,235,014 (12.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We keep the model small for now:

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# EPOCHS = 100

# model = build_model(tf.keras.Input(shape=(input_size, input_size, 1)))
# reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
# history = model.fit(train_ds,
#                     steps_per_epoch=(len(train_image_files) // BATCH_SIZE),
#                     validation_data=validation_ds, validation_steps=1,
#                     epochs=EPOCHS,
#                     callbacks=[reduce_lr] # Add callback to model.fit
#                     )

# %%
from tensorflow.keras.callbacks import EarlyStopping

EPOCHS = 1000

model = build_model(tf.keras.Input(shape=(input_size, input_size, 1)))

early_stopping = EarlyStopping(monitor='val_regressor_head_mse', mode='min', patience=25, restore_best_weights=True) # Add EarlyStopping callback

history = model.fit(train_ds,
                    steps_per_epoch=(len(train_image_files) // BATCH_SIZE),
                    validation_data=validation_ds,
                    epochs=EPOCHS,
                    callbacks=[early_stopping] # Pass the callback to model.fit
                    )
# Out:
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - classifier_head_accuracy: 0.2159 - classifier_head_loss: 23.0742 - loss: 6670.0806 - regressor_head_loss: 6644.6230 - regressor_head_mse: 6644.6230 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 6.7634 - val_loss: 7252.0010 - val_regressor_head_loss: 7242.6279 - val_regressor_head_mse: 7242.6279
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8647 - classifier_head_loss: 1.5120 - loss: 4279.8057 - regressor_head_loss: 4275.6812 - regressor_head_mse: 4275.6812 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.3270 - val_loss: 6782.1616 - val_regressor_head_loss: 6778.0825 - val_regressor_head_mse: 6778.0825
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8612 - classifier_head_loss: 0.6445 - loss: 4063.4265 - regressor_head_loss: 4059.9783 - regressor_head_mse: 4059.9783 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.8996 - val_loss: 6875.9106 - val_regressor_head_loss: 6870.9478 - val_regressor_head_mse: 6870.9478
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8754 - classifier_head_loss: 0.6386 - loss: 3777.6252 - regressor_head_loss: 3773.8589 - regressor_head_mse: 3773.8589 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.9060 - val_loss: 5993.4131 - val_regressor_head_loss: 5987.9082 - val_regressor_head_mse: 5987.9072
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8289 - classifier_head_loss: 0.8482 - loss: 4176.5000 - regressor_head_loss: 4171.8296 - regressor_head_mse: 4171.8296 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.8861 - val_loss: 7416.6846 - val_regressor_head_loss: 7410.3711 - val_regressor_head_mse: 7410.3706
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8691 - classifier_head_loss: 0.6219 - loss: 3688.2517 - regressor_head_loss: 3683.0796 - regressor_head_mse: 3683.0796 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.1045 - val_loss: 7798.0073 - val_regressor_head_loss: 7790.7461 - val_regressor_head_mse: 7790.7456
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8615 - classifier_head_loss: 0.6165 - loss: 3557.0869 - regressor_head_loss: 3551.2087 - regressor_head_mse: 3551.2087 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.4796 - val_loss: 6721.2334 - val_regressor_head_loss: 6714.0361 - val_regressor_head_mse: 6714.0361
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8653 - classifier_head_loss: 0.5963 - loss: 3502.4614 - regressor_head_loss: 3496.0344 - regressor_head_mse: 3496.0344 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.9037 - val_loss: 6809.3193 - val_regressor_head_loss: 6801.1162 - val_regressor_head_mse: 6801.1157
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8913 - classifier_head_loss: 0.4990 - loss: 3330.1433 - regressor_head_loss: 3323.2307 - regressor_head_mse: 3323.2307 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.2515 - val_loss: 6335.9780 - val_regressor_head_loss: 6326.7866 - val_regressor_head_mse: 6326.7861
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8685 - classifier_head_loss: 0.5752 - loss: 3366.0188 - regressor_head_loss: 3358.3840 - regressor_head_mse: 3358.3840 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.0578 - val_loss: 6006.6953 - val_regressor_head_loss: 5997.2178 - val_regressor_head_mse: 5997.2163
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8746 - classifier_head_loss: 0.5897 - loss: 3335.8125 - regressor_head_loss: 3327.6189 - regressor_head_mse: 3327.6189 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.9155 - val_loss: 6054.1431 - val_regressor_head_loss: 6044.1562 - val_regressor_head_mse: 6044.1562
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8607 - classifier_head_loss: 0.5694 - loss: 3486.5984 - regressor_head_loss: 3477.7913 - regressor_head_mse: 3477.7913 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.7779 - val_loss: 6450.3672 - val_regressor_head_loss: 6439.7383 - val_regressor_head_mse: 6439.7383
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8749 - classifier_head_loss: 0.5204 - loss: 3178.9937 - regressor_head_loss: 3169.4702 - regressor_head_mse: 3169.4702 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.0461 - val_loss: 6503.9819 - val_regressor_head_loss: 6492.4473 - val_regressor_head_mse: 6492.4468
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8758 - classifier_head_loss: 0.5257 - loss: 3083.5503 - regressor_head_loss: 3073.3022 - regressor_head_mse: 3073.3022 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.4271 - val_loss: 5764.8594 - val_regressor_head_loss: 5753.0190 - val_regressor_head_mse: 5753.0190
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8842 - classifier_head_loss: 0.4552 - loss: 3106.7371 - regressor_head_loss: 3095.5813 - regressor_head_mse: 3095.5813 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.4570 - val_loss: 6852.7812 - val_regressor_head_loss: 6839.6680 - val_regressor_head_mse: 6839.6675
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8798 - classifier_head_loss: 0.4823 - loss: 3081.4739 - regressor_head_loss: 3069.0481 - regressor_head_mse: 3069.0481 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.3700 - val_loss: 6844.3501 - val_regressor_head_loss: 6830.0205 - val_regressor_head_mse: 6830.0200
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8838 - classifier_head_loss: 0.4495 - loss: 2976.2664 - regressor_head_loss: 2962.5117 - regressor_head_mse: 2962.5117 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 1.7812 - val_loss: 6202.2827 - val_regressor_head_loss: 6185.8662 - val_regressor_head_mse: 6185.8662
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8874 - classifier_head_loss: 0.4021 - loss: 2882.6985 - regressor_head_loss: 2867.2490 - regressor_head_mse: 2867.2490 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.9463 - val_loss: 7242.8374 - val_regressor_head_loss: 7223.3862 - val_regressor_head_mse: 7223.3862
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.8737 - classifier_head_loss: 0.4860 - loss: 2926.7537 - regressor_head_loss: 2909.4143 - regressor_head_mse: 2909.4143 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.4677 - val_loss: 5573.1787 - val_regressor_head_loss: 5552.4600 - val_regressor_head_mse: 5552.4600
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9003 - classifier_head_loss: 0.4430 - loss: 2624.9165 - regressor_head_loss: 2605.7271 - regressor_head_mse: 2605.7271 - val_classifier_head_accuracy: 0.5268 - val_classifier_head_loss: 1.9815 - val_loss: 5919.5127 - val_regressor_head_loss: 5897.1865 - val_regressor_head_mse: 5897.1865
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8978 - classifier_head_loss: 0.5043 - loss: 2634.3623 - regressor_head_loss: 2613.0964 - regressor_head_mse: 2613.0964 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.7675 - val_loss: 5979.7456 - val_regressor_head_loss: 5954.5879 - val_regressor_head_mse: 5954.5869
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.8920 - classifier_head_loss: 0.4585 - loss: 2549.4055 - regressor_head_loss: 2526.0518 - regressor_head_mse: 2526.0518 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.7464 - val_loss: 7081.3203 - val_regressor_head_loss: 7053.9399 - val_regressor_head_mse: 7053.9399
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8950 - classifier_head_loss: 0.5057 - loss: 2601.4622 - regressor_head_loss: 2575.9644 - regressor_head_mse: 2575.9644 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.8337 - val_loss: 6427.7964 - val_regressor_head_loss: 6398.2793 - val_regressor_head_mse: 6398.2788
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8929 - classifier_head_loss: 0.5082 - loss: 2347.1572 - regressor_head_loss: 2319.5596 - regressor_head_mse: 2319.5596 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.6108 - val_loss: 6000.5391 - val_regressor_head_loss: 5969.3057 - val_regressor_head_mse: 5969.3057
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9010 - classifier_head_loss: 0.4661 - loss: 2230.3142 - regressor_head_loss: 2200.7676 - regressor_head_mse: 2200.7676 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.5023 - val_loss: 5872.6572 - val_regressor_head_loss: 5839.5347 - val_regressor_head_mse: 5839.5347
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8863 - classifier_head_loss: 0.5119 - loss: 2220.5627 - regressor_head_loss: 2189.0496 - regressor_head_mse: 2189.0496 - val_classifier_head_accuracy: 0.5022 - val_classifier_head_loss: 2.7182 - val_loss: 6258.7690 - val_regressor_head_loss: 6223.5752 - val_regressor_head_mse: 6223.5747
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9147 - classifier_head_loss: 0.4617 - loss: 2058.7407 - regressor_head_loss: 2025.4618 - regressor_head_mse: 2025.4618 - val_classifier_head_accuracy: 0.5246 - val_classifier_head_loss: 2.8109 - val_loss: 5282.7256 - val_regressor_head_loss: 5245.7305 - val_regressor_head_mse: 5245.7300
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9000 - classifier_head_loss: 0.5135 - loss: 1980.9388 - regressor_head_loss: 1945.9128 - regressor_head_mse: 1945.9128 - val_classifier_head_accuracy: 0.5335 - val_classifier_head_loss: 2.4460 - val_loss: 5755.3291 - val_regressor_head_loss: 5717.0913 - val_regressor_head_mse: 5717.0908
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9035 - classifier_head_loss: 0.5465 - loss: 1812.5001 - regressor_head_loss: 1775.8005 - regressor_head_mse: 1775.8005 - val_classifier_head_accuracy: 0.5424 - val_classifier_head_loss: 2.5508 - val_loss: 4941.0312 - val_regressor_head_loss: 4901.0498 - val_regressor_head_mse: 4901.0498
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9061 - classifier_head_loss: 0.5440 - loss: 1768.8508 - regressor_head_loss: 1730.5691 - regressor_head_mse: 1730.5691 - val_classifier_head_accuracy: 0.5379 - val_classifier_head_loss: 2.7120 - val_loss: 4243.7417 - val_regressor_head_loss: 4202.2158 - val_regressor_head_mse: 4202.2158
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9017 - classifier_head_loss: 0.5999 - loss: 1650.4650 - regressor_head_loss: 1610.5686 - regressor_head_mse: 1610.5686 - val_classifier_head_accuracy: 0.5402 - val_classifier_head_loss: 3.1670 - val_loss: 5523.2979 - val_regressor_head_loss: 5479.5449 - val_regressor_head_mse: 5479.5444
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9093 - classifier_head_loss: 0.4749 - loss: 1573.6147 - regressor_head_loss: 1532.3000 - regressor_head_mse: 1532.3000 - val_classifier_head_accuracy: 0.5402 - val_classifier_head_loss: 2.5147 - val_loss: 4389.7397 - val_regressor_head_loss: 4345.4614 - val_regressor_head_mse: 4345.4614
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.8998 - classifier_head_loss: 0.4835 - loss: 1535.3859 - regressor_head_loss: 1492.8159 - regressor_head_mse: 1492.8159 - val_classifier_head_accuracy: 0.5312 - val_classifier_head_loss: 2.8700 - val_loss: 4455.6646 - val_regressor_head_loss: 4409.6255 - val_regressor_head_mse: 4409.6255
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9149 - classifier_head_loss: 0.3939 - loss: 1397.1859 - regressor_head_loss: 1353.3472 - regressor_head_mse: 1353.3472 - val_classifier_head_accuracy: 0.5357 - val_classifier_head_loss: 3.2521 - val_loss: 4717.4351 - val_regressor_head_loss: 4669.8271 - val_regressor_head_mse: 4669.8271
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9232 - classifier_head_loss: 0.3913 - loss: 1268.1069 - regressor_head_loss: 1223.0646 - regressor_head_mse: 1223.0646 - val_classifier_head_accuracy: 0.5335 - val_classifier_head_loss: 2.9885 - val_loss: 4411.6533 - val_regressor_head_loss: 4362.9702 - val_regressor_head_mse: 4362.9697
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9275 - classifier_head_loss: 0.3573 - loss: 1188.8668 - regressor_head_loss: 1142.5476 - regressor_head_mse: 1142.5476 - val_classifier_head_accuracy: 0.5402 - val_classifier_head_loss: 2.5631 - val_loss: 3863.3301 - val_regressor_head_loss: 3813.9907 - val_regressor_head_mse: 3813.9907
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9256 - classifier_head_loss: 0.3581 - loss: 1162.8960 - regressor_head_loss: 1115.4470 - regressor_head_mse: 1115.4470 - val_classifier_head_accuracy: 0.5513 - val_classifier_head_loss: 2.6398 - val_loss: 4103.9604 - val_regressor_head_loss: 4053.3223 - val_regressor_head_mse: 4053.3220
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9257 - classifier_head_loss: 0.3434 - loss: 1040.4814 - regressor_head_loss: 991.8946 - regressor_head_mse: 991.8946 - val_classifier_head_accuracy: 0.5402 - val_classifier_head_loss: 3.2454 - val_loss: 4168.4204 - val_regressor_head_loss: 4116.1367 - val_regressor_head_mse: 4116.1362
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9183 - classifier_head_loss: 0.3563 - loss: 1069.3383 - regressor_head_loss: 1019.6911 - regressor_head_mse: 1019.6911 - val_classifier_head_accuracy: 0.5603 - val_classifier_head_loss: 2.9739 - val_loss: 4283.2222 - val_regressor_head_loss: 4230.0977 - val_regressor_head_mse: 4230.0972
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9303 - classifier_head_loss: 0.3296 - loss: 995.4714 - regressor_head_loss: 944.7321 - regressor_head_mse: 944.7321 - val_classifier_head_accuracy: 0.5379 - val_classifier_head_loss: 3.6030 - val_loss: 4475.9717 - val_regressor_head_loss: 4421.1460 - val_regressor_head_mse: 4421.1455
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9357 - classifier_head_loss: 0.3209 - loss: 937.9191 - regressor_head_loss: 886.1815 - regressor_head_mse: 886.1815 - val_classifier_head_accuracy: 0.5491 - val_classifier_head_loss: 2.8458 - val_loss: 3452.4905 - val_regressor_head_loss: 3397.4353 - val_regressor_head_mse: 3397.4351
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9297 - classifier_head_loss: 0.3083 - loss: 893.6008 - regressor_head_loss: 840.8394 - regressor_head_mse: 840.8394 - val_classifier_head_accuracy: 0.5402 - val_classifier_head_loss: 3.1562 - val_loss: 4086.9995 - val_regressor_head_loss: 4030.5984 - val_regressor_head_mse: 4030.5981
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9289 - classifier_head_loss: 0.2938 - loss: 767.2147 - regressor_head_loss: 713.5292 - regressor_head_mse: 713.5292 - val_classifier_head_accuracy: 0.5491 - val_classifier_head_loss: 2.5389 - val_loss: 3754.1050 - val_regressor_head_loss: 3697.3457 - val_regressor_head_mse: 3697.3455
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9264 - classifier_head_loss: 0.3258 - loss: 781.6984 - regressor_head_loss: 726.9785 - regressor_head_mse: 726.9785 - val_classifier_head_accuracy: 0.5268 - val_classifier_head_loss: 3.6984 - val_loss: 4083.5122 - val_regressor_head_loss: 4024.5447 - val_regressor_head_mse: 4024.5447
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9340 - classifier_head_loss: 0.2464 - loss: 682.7195 - regressor_head_loss: 626.9734 - regressor_head_mse: 626.9734 - val_classifier_head_accuracy: 0.5424 - val_classifier_head_loss: 2.9724 - val_loss: 3961.7078 - val_regressor_head_loss: 3902.6824 - val_regressor_head_mse: 3902.6824
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9317 - classifier_head_loss: 0.2647 - loss: 673.8084 - regressor_head_loss: 617.3570 - regressor_head_mse: 617.3570 - val_classifier_head_accuracy: 0.5424 - val_classifier_head_loss: 2.9264 - val_loss: 3707.6067 - val_regressor_head_loss: 3647.9932 - val_regressor_head_mse: 3647.9929
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9247 - classifier_head_loss: 0.2919 - loss: 649.4610 - regressor_head_loss: 592.2183 - regressor_head_mse: 592.2183 - val_classifier_head_accuracy: 0.5469 - val_classifier_head_loss: 3.2746 - val_loss: 4066.5312 - val_regressor_head_loss: 4005.5264 - val_regressor_head_mse: 4005.5261
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9374 - classifier_head_loss: 0.2047 - loss: 594.6522 - regressor_head_loss: 536.5150 - regressor_head_mse: 536.5150 - val_classifier_head_accuracy: 0.5670 - val_classifier_head_loss: 2.4302 - val_loss: 3832.9998 - val_regressor_head_loss: 3772.0681 - val_regressor_head_mse: 3772.0681
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9447 - classifier_head_loss: 0.2087 - loss: 592.4295 - regressor_head_loss: 533.5525 - regressor_head_mse: 533.5525 - val_classifier_head_accuracy: 0.5647 - val_classifier_head_loss: 2.5169 - val_loss: 3359.9526 - val_regressor_head_loss: 3298.1274 - val_regressor_head_mse: 3298.1272
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9411 - classifier_head_loss: 0.1938 - loss: 579.2447 - regressor_head_loss: 519.6605 - regressor_head_mse: 519.6605 - val_classifier_head_accuracy: 0.5714 - val_classifier_head_loss: 2.3172 - val_loss: 3283.2512 - val_regressor_head_loss: 3221.2302 - val_regressor_head_mse: 3221.2300
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9303 - classifier_head_loss: 0.2067 - loss: 568.7844 - regressor_head_loss: 508.7062 - regressor_head_mse: 508.7062 - val_classifier_head_accuracy: 0.5558 - val_classifier_head_loss: 2.6617 - val_loss: 3733.6216 - val_regressor_head_loss: 3670.4756 - val_regressor_head_mse: 3670.4751
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9299 - classifier_head_loss: 0.2285 - loss: 508.2003 - regressor_head_loss: 447.3474 - regressor_head_mse: 447.3474 - val_classifier_head_accuracy: 0.5558 - val_classifier_head_loss: 2.4627 - val_loss: 3624.4233 - val_regressor_head_loss: 3561.0325 - val_regressor_head_mse: 3561.0320
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9441 - classifier_head_loss: 0.1656 - loss: 490.6999 - regressor_head_loss: 429.5311 - regressor_head_mse: 429.5311 - val_classifier_head_accuracy: 0.5536 - val_classifier_head_loss: 2.7613 - val_loss: 3872.3059 - val_regressor_head_loss: 3808.1858 - val_regressor_head_mse: 3808.1858
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9318 - classifier_head_loss: 0.2167 - loss: 470.3095 - regressor_head_loss: 408.6259 - regressor_head_mse: 408.6259 - val_classifier_head_accuracy: 0.5558 - val_classifier_head_loss: 2.7853 - val_loss: 3988.7844 - val_regressor_head_loss: 3924.1370 - val_regressor_head_mse: 3924.1370
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9527 - classifier_head_loss: 0.1454 - loss: 479.3618 - regressor_head_loss: 417.2041 - regressor_head_mse: 417.2041 - val_classifier_head_accuracy: 0.5603 - val_classifier_head_loss: 2.5553 - val_loss: 3807.4727 - val_regressor_head_loss: 3742.3330 - val_regressor_head_mse: 3742.3333
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9470 - classifier_head_loss: 0.1598 - loss: 456.8007 - regressor_head_loss: 393.9492 - regressor_head_mse: 393.9492 - val_classifier_head_accuracy: 0.5692 - val_classifier_head_loss: 2.3385 - val_loss: 3858.4590 - val_regressor_head_loss: 3793.1030 - val_regressor_head_mse: 3793.1030
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9429 - classifier_head_loss: 0.1527 - loss: 421.2772 - regressor_head_loss: 358.0031 - regressor_head_mse: 358.0031 - val_classifier_head_accuracy: 0.5692 - val_classifier_head_loss: 2.1066 - val_loss: 3732.9688 - val_regressor_head_loss: 3667.3333 - val_regressor_head_mse: 3667.3333
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9502 - classifier_head_loss: 0.1535 - loss: 407.5198 - regressor_head_loss: 343.6735 - regressor_head_mse: 343.6735 - val_classifier_head_accuracy: 0.5670 - val_classifier_head_loss: 2.5721 - val_loss: 3812.6528 - val_regressor_head_loss: 3745.8794 - val_regressor_head_mse: 3745.8792
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9401 - classifier_head_loss: 0.1452 - loss: 395.1502 - regressor_head_loss: 330.7128 - regressor_head_mse: 330.7128 - val_classifier_head_accuracy: 0.5647 - val_classifier_head_loss: 2.5764 - val_loss: 3917.0452 - val_regressor_head_loss: 3849.4956 - val_regressor_head_mse: 3849.4956
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9547 - classifier_head_loss: 0.1418 - loss: 388.7686 - regressor_head_loss: 323.5701 - regressor_head_mse: 323.5701 - val_classifier_head_accuracy: 0.5826 - val_classifier_head_loss: 2.1795 - val_loss: 3425.8796 - val_regressor_head_loss: 3358.4326 - val_regressor_head_mse: 3358.4324
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9630 - classifier_head_loss: 0.1021 - loss: 359.3456 - regressor_head_loss: 293.8811 - regressor_head_mse: 293.8811 - val_classifier_head_accuracy: 0.5804 - val_classifier_head_loss: 2.0759 - val_loss: 3241.7209 - val_regressor_head_loss: 3173.9807 - val_regressor_head_mse: 3173.9805
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9538 - classifier_head_loss: 0.1188 - loss: 390.8944 - regressor_head_loss: 324.9961 - regressor_head_mse: 324.9961 - val_classifier_head_accuracy: 0.5670 - val_classifier_head_loss: 2.1098 - val_loss: 3472.0056 - val_regressor_head_loss: 3403.8062 - val_regressor_head_mse: 3403.8062
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9540 - classifier_head_loss: 0.1146 - loss: 346.6753 - regressor_head_loss: 280.3906 - regressor_head_mse: 280.3906 - val_classifier_head_accuracy: 0.5781 - val_classifier_head_loss: 2.1138 - val_loss: 3583.2249 - val_regressor_head_loss: 3514.7148 - val_regressor_head_mse: 3514.7148
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9716 - classifier_head_loss: 0.0912 - loss: 336.3857 - regressor_head_loss: 269.8333 - regressor_head_mse: 269.8333 - val_classifier_head_accuracy: 0.5491 - val_classifier_head_loss: 2.5598 - val_loss: 3648.5806 - val_regressor_head_loss: 3579.3237 - val_regressor_head_mse: 3579.3235
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9440 - classifier_head_loss: 0.1222 - loss: 335.7220 - regressor_head_loss: 268.8198 - regressor_head_mse: 268.8198 - val_classifier_head_accuracy: 0.5625 - val_classifier_head_loss: 2.4402 - val_loss: 3698.4019 - val_regressor_head_loss: 3628.9365 - val_regressor_head_mse: 3628.9360
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9655 - classifier_head_loss: 0.1021 - loss: 333.5729 - regressor_head_loss: 266.3673 - regressor_head_mse: 266.3673 - val_classifier_head_accuracy: 0.5670 - val_classifier_head_loss: 2.3827 - val_loss: 3417.8906 - val_regressor_head_loss: 3348.1157 - val_regressor_head_mse: 3348.1155
# Epoch 67/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9671 - classifier_head_loss: 0.0965 - loss: 370.2093 - regressor_head_loss: 302.6048 - regressor_head_mse: 302.6048 - val_classifier_head_accuracy: 0.5692 - val_classifier_head_loss: 2.3311 - val_loss: 3645.6992 - val_regressor_head_loss: 3575.5776 - val_regressor_head_mse: 3575.5776
# Epoch 68/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9631 - classifier_head_loss: 0.0910 - loss: 346.8428 - regressor_head_loss: 278.8880 - regressor_head_mse: 278.8880 - val_classifier_head_accuracy: 0.5737 - val_classifier_head_loss: 2.3888 - val_loss: 3596.4341 - val_regressor_head_loss: 3525.9736 - val_regressor_head_mse: 3525.9734
# Epoch 69/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9623 - classifier_head_loss: 0.0835 - loss: 293.1870 - regressor_head_loss: 224.9174 - regressor_head_mse: 224.9174 - val_classifier_head_accuracy: 0.5491 - val_classifier_head_loss: 2.5582 - val_loss: 3490.1770 - val_regressor_head_loss: 3419.1621 - val_regressor_head_mse: 3419.1621
# Epoch 70/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - classifier_head_accuracy: 0.9585 - classifier_head_loss: 0.0912 - loss: 305.3725 - regressor_head_loss: 236.7557 - regressor_head_mse: 236.7557 - val_classifier_head_accuracy: 0.5804 - val_classifier_head_loss: 2.1670 - val_loss: 3266.4883 - val_regressor_head_loss: 3195.5972 - val_regressor_head_mse: 3195.5972
# Epoch 71/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9747 - classifier_head_loss: 0.0775 - loss: 287.5985 - regressor_head_loss: 218.7478 - regressor_head_mse: 218.7478 - val_classifier_head_accuracy: 0.5714 - val_classifier_head_loss: 2.2111 - val_loss: 3576.1638 - val_regressor_head_loss: 3505.0623 - val_regressor_head_mse: 3505.0620
# Epoch 72/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9791 - classifier_head_loss: 0.0652 - loss: 296.4191 - regressor_head_loss: 227.3824 - regressor_head_mse: 227.3824 - val_classifier_head_accuracy: 0.5826 - val_classifier_head_loss: 2.0647 - val_loss: 3283.5056 - val_regressor_head_loss: 3212.2710 - val_regressor_head_mse: 3212.2708
# Epoch 73/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9702 - classifier_head_loss: 0.0754 - loss: 291.6101 - regressor_head_loss: 222.3017 - regressor_head_mse: 222.3017 - val_classifier_head_accuracy: 0.5625 - val_classifier_head_loss: 2.4125 - val_loss: 3747.7310 - val_regressor_head_loss: 3675.8879 - val_regressor_head_mse: 3675.8879
# Epoch 74/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9643 - classifier_head_loss: 0.0835 - loss: 308.1835 - regressor_head_loss: 238.5562 - regressor_head_mse: 238.5562 - val_classifier_head_accuracy: 0.5670 - val_classifier_head_loss: 2.1624 - val_loss: 3463.5242 - val_regressor_head_loss: 3391.4253 - val_regressor_head_mse: 3391.4253
# Epoch 75/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9591 - classifier_head_loss: 0.0932 - loss: 278.0357 - regressor_head_loss: 207.9570 - regressor_head_mse: 207.9570 - val_classifier_head_accuracy: 0.5513 - val_classifier_head_loss: 2.4606 - val_loss: 3724.2351 - val_regressor_head_loss: 3651.8203 - val_regressor_head_mse: 3651.8203
# Epoch 76/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9578 - classifier_head_loss: 0.0899 - loss: 276.8218 - regressor_head_loss: 206.7480 - regressor_head_mse: 206.7480 - val_classifier_head_accuracy: 0.5647 - val_classifier_head_loss: 2.3656 - val_loss: 3664.2817 - val_regressor_head_loss: 3591.8818 - val_regressor_head_mse: 3591.8816
# Epoch 77/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9821 - classifier_head_loss: 0.0768 - loss: 261.4095 - regressor_head_loss: 191.2268 - regressor_head_mse: 191.2268 - val_classifier_head_accuracy: 0.5335 - val_classifier_head_loss: 4.8372 - val_loss: 3959.8542 - val_regressor_head_loss: 3884.1934 - val_regressor_head_mse: 3884.1931
# Epoch 78/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9428 - classifier_head_loss: 0.1473 - loss: 286.9441 - regressor_head_loss: 215.8348 - regressor_head_mse: 215.8348 - val_classifier_head_accuracy: 0.5558 - val_classifier_head_loss: 2.9505 - val_loss: 3484.9448 - val_regressor_head_loss: 3411.0095 - val_regressor_head_mse: 3411.0095
# Epoch 79/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9700 - classifier_head_loss: 0.0834 - loss: 267.6545 - regressor_head_loss: 196.6014 - regressor_head_mse: 196.6014 - val_classifier_head_accuracy: 0.5692 - val_classifier_head_loss: 2.4421 - val_loss: 3648.6714 - val_regressor_head_loss: 3575.2114 - val_regressor_head_mse: 3575.2114
# Epoch 80/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9755 - classifier_head_loss: 0.0573 - loss: 252.8142 - regressor_head_loss: 181.7139 - regressor_head_mse: 181.7139 - val_classifier_head_accuracy: 0.5804 - val_classifier_head_loss: 1.9870 - val_loss: 3287.7114 - val_regressor_head_loss: 3214.6475 - val_regressor_head_mse: 3214.6477
# Epoch 81/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9838 - classifier_head_loss: 0.0599 - loss: 276.7540 - regressor_head_loss: 205.5670 - regressor_head_mse: 205.5670 - val_classifier_head_accuracy: 0.5714 - val_classifier_head_loss: 2.6047 - val_loss: 3621.0911 - val_regressor_head_loss: 3547.3345 - val_regressor_head_mse: 3547.3342
# Epoch 82/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9796 - classifier_head_loss: 0.0657 - loss: 251.4887 - regressor_head_loss: 180.1732 - regressor_head_mse: 180.1732 - val_classifier_head_accuracy: 0.5714 - val_classifier_head_loss: 2.3727 - val_loss: 3629.8850 - val_regressor_head_loss: 3555.8789 - val_regressor_head_mse: 3555.8789
# Epoch 83/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9875 - classifier_head_loss: 0.0473 - loss: 263.4117 - regressor_head_loss: 191.7621 - regressor_head_mse: 191.7621 - val_classifier_head_accuracy: 0.5580 - val_classifier_head_loss: 2.5808 - val_loss: 3701.8364 - val_regressor_head_loss: 3627.6807 - val_regressor_head_mse: 3627.6809
# Epoch 84/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - classifier_head_accuracy: 0.9822 - classifier_head_loss: 0.0630 - loss: 256.9750 - regressor_head_loss: 185.3312 - regressor_head_mse: 185.3312 - val_classifier_head_accuracy: 0.5804 - val_classifier_head_loss: 2.1013 - val_loss: 3617.1858 - val_regressor_head_loss: 3543.4399 - val_regressor_head_mse: 3543.4397
# Epoch 85/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9798 - classifier_head_loss: 0.0492 - loss: 254.9248 - regressor_head_loss: 183.1107 - regressor_head_mse: 183.1107 - val_classifier_head_accuracy: 0.5804 - val_classifier_head_loss: 2.3321 - val_loss: 3822.2163 - val_regressor_head_loss: 3747.9243 - val_regressor_head_mse: 3747.9241
# Epoch 86/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - classifier_head_accuracy: 0.9894 - classifier_head_loss: 0.0472 - loss: 254.9834 - regressor_head_loss: 182.9871 - regressor_head_mse: 182.9871 - val_classifier_head_accuracy: 0.5737 - val_classifier_head_loss: 2.3112 - val_loss: 3798.9106 - val_regressor_head_loss: 3724.6753 - val_regressor_head_mse: 3724.6753

# %%
plt.plot(history.history['classifier_head_accuracy'])
plt.plot(history.history['val_classifier_head_accuracy'])
plt.title('Classification Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['classifier_head_loss'])
plt.plot(history.history['val_classifier_head_loss'])
plt.title('Classification Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['loss'])
plt.title('Overall Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['regressor_head_loss'])
plt.plot(history.history['val_regressor_head_loss'])
plt.title('Bounding Box Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['regressor_head_mse'])
plt.plot(history.history['val_regressor_head_mse'])
plt.title('Bounding Box Regression Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ## Evaluation

# %%
# IoU evaluation

def calculate_iou(box1, box2):
    """Calculates the Intersection over Union (IoU) of two bounding boxes.

    Args:
        box1: A NumPy array representing the first bounding box [xmin, ymin, xmax, ymax].
        box2: A NumPy array representing the second bounding box [xmin, ymin, xmax, ymax].

    Returns:
        The IoU value (a float between 0 and 1).
    """
    # Determine the coordinates of the intersection rectangle
    x_left = max(box1[0], box2[0])
    y_top = max(box1[1], box2[1])
    x_right = min(box1[2], box2[2])
    y_bottom = min(box1[3], box2[3])

    # Check if there is an intersection
    if x_right < x_left or y_bottom < y_top:
        return 0.0

    # Calculate the area of intersection
    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    # Calculate the area of both bounding boxes
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])

    # Calculate the IoU
    iou = intersection_area / float(box1_area + box2_area - intersection_area)
    return iou

# %%
# Predict some examples from the test set

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

for image, (label, box) in test_ds.take(1):  # Get the first batch
    print(len(image))
    # Get predictions
    predictions = model.predict(image)

    # Assuming 'predictions' is a tuple with classification and bounding box
    predicted_labels = predictions[0]
    predicted_boxes = predictions[1]


    for i in range(10): # predict 10 images from the batch
        # Convert image to NumPy array
        print(image[i].numpy().shape)
        img = image[i].numpy()[:, :, 0]

        # Get true values
        true_label = label[i].numpy().argmax()
        true_box = box[i].numpy()

        # Get predicted values
        pred_label = predicted_labels[i].argmax()
        pred_box = predicted_boxes[i]
        print(f"Image {i}: True Label: {true_label} Pred Label: {pred_label}, True box {true_box} Pred box {pred_box}")

        # Create plot
        fig, ax = plt.subplots(1)
        ax.imshow(img, cmap='gray')

        # Add true bounding box
        rect_true = patches.Rectangle((true_box[0], true_box[1]), (true_box[2]-true_box[0]), (true_box[3]-true_box[1]), linewidth=2, edgecolor='g', facecolor='none', label='True Box')
        ax.add_patch(rect_true)

        # Add predicted bounding box
        rect_pred = patches.Rectangle((pred_box[0], pred_box[1]), (pred_box[2]-pred_box[0]), (pred_box[3]-pred_box[1]), linewidth=2, edgecolor='r', facecolor='none', label='Predicted Box')
        ax.add_patch(rect_pred)

        ax.legend()

        # Calculate IoU
        iou = calculate_iou(true_box, pred_box)
        print(f"Image {i}: IoU: {iou}")

        # Add IoU to the plot (optional)
        plt.text(0.5, 0.95, f"IoU: {iou:.2f}", ha='center', va='top', transform=ax.transAxes)  # Position the text

        # Display the plot
        plt.show()
# Out:
# 53
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step
# (244, 244, 1)
# Image 0: True Label: 1 Pred Label: 1, True box [143.  75. 200. 109.] Pred box [124.777374  51.02512  189.45493  102.81381 ]
# Image 0: IoU: 0.32338780267606043
# (244, 244, 1)
# Image 1: True Label: 1 Pred Label: 1, True box [ 79.  47. 118.  97.] Pred box [ 59.897354  71.71678  114.98346  131.50699 ]
# Image 1: IoU: 0.209924552882498
# (244, 244, 1)
# Image 2: True Label: 1 Pred Label: 1, True box [ 58.  66.  83. 118.] Pred box [ 52.51055  62.06691 106.35496 111.34435]
# Image 2: IoU: 0.4020308296901792
# (244, 244, 1)
# Image 3: True Label: 1 Pred Label: 1, True box [67. 41. 93. 99.] Pred box [ 85.855576  70.928215 124.64802  133.76912 ]
# Image 3: IoU: 0.053550407289391144
# (244, 244, 1)
# Image 4: True Label: 1 Pred Label: 1, True box [110. 139. 196. 176.] Pred box [112.04704  66.62775 189.98051 118.19035]
# Image 4: IoU: 0.0
# (244, 244, 1)
# Image 5: True Label: 1 Pred Label: 1, True box [106. 129. 174. 170.] Pred box [123.27468  68.88306 190.14548 121.79895]
# Image 5: IoU: 0.0
# (244, 244, 1)
# Image 6: True Label: 1 Pred Label: 1, True box [ 15. 151. 100. 199.] Pred box [109.66945 102.08343 170.7341  166.5192 ]
# Image 6: IoU: 0.0
# (244, 244, 1)
# Image 7: True Label: 1 Pred Label: 1, True box [ 43.  88.  77. 139.] Pred box [ 56.683292  79.04257  114.697784 134.20686 ]
# Image 7: IoU: 0.23495383665937503
# (244, 244, 1)
# Image 8: True Label: 1 Pred Label: 1, True box [ 78.  48. 178.  79.] Pred box [ 93.72583  69.92672 193.17642 126.27954]
# Image 8: IoU: 0.09630657150495303
# (244, 244, 1)
# Image 9: True Label: 1 Pred Label: 1, True box [ 48. 120. 117. 156.] Pred box [ 61.27349   63.340435 126.90315  117.10647 ]
# Image 9: IoU: 0.0
